# %%
import numpy as np
import pytorch_lightning as pl
import torch
import random
from torch_geometric.transforms import ToUndirected
from torch_geometric.nn import Node2Vec
from torch_geometric.utils import negative_sampling
from torch_geometric.loader import NeighborLoader
from torch_geometric.loader.base import BaseDataLoader
from scipy.sparse import csr_matrix

import experiments
import ml
from experiments import cosine_cdist, euclidean_cdist
from shared.constants import TMP_PATH
# Out:
# [2022-02-15 12:43:47,280][simple_parsing.helpers.serialization.serializable][DEBUG] Registering a new Serializable subclass: <class 'simple_parsing.helpers.serialization.serializable.Serializable'>
# [2022-02-15 12:43:47,282][simple_parsing.helpers.serialization.serializable][DEBUG] parents: [<class 'simple_parsing.helpers.serialization.serializable.SerializableMixin'>]
# [2022-02-15 12:43:47,283][simple_parsing.helpers.serialization.serializable][DEBUG] Registering a new Serializable subclass: <class 'simple_parsing.helpers.serialization.serializable.FrozenSerializable'>
# [2022-02-15 12:43:47,283][simple_parsing.helpers.serialization.serializable][DEBUG] parents: [<class 'simple_parsing.helpers.serialization.serializable.SerializableMixin'>]
# [2022-02-15 12:43:47,285][simple_parsing.helpers.serialization.serializable][DEBUG] Registering a new Serializable subclass: <class 'simple_parsing.helpers.serialization.serializable.SimpleSerializable'>
# [2022-02-15 12:43:47,288][simple_parsing.helpers.serialization.serializable][DEBUG] Registering a new Serializable subclass: <class 'simple_parsing.helpers.serialization.yaml_serialization.YamlSerializable'>
# [2022-02-15 12:43:47,289][simple_parsing.helpers.serialization.serializable][DEBUG] parents: [<class 'simple_parsing.helpers.serialization.serializable.Serializable'>, <class 'simple_parsing.helpers.serialization.serializable.SerializableMixin'>]
# [2022-02-15 12:43:47,290][simple_parsing.helpers.serialization.serializable][DEBUG] Parent class <class 'simple_parsing.helpers.serialization.serializable.Serializable'> has decode_into_subclasses = False
# [2022-02-15 12:43:47,296][simple_parsing.helpers.serialization.serializable][DEBUG] Registering a new Serializable subclass: <class 'simple_parsing.helpers.hparams.hyperparameters.BoundInfo'>
# [2022-02-15 12:43:47,297][simple_parsing.helpers.serialization.serializable][DEBUG] parents: [<class 'simple_parsing.helpers.serialization.serializable.Serializable'>, <class 'simple_parsing.helpers.serialization.serializable.SerializableMixin'>]
# [2022-02-15 12:43:47,298][simple_parsing.helpers.serialization.serializable][DEBUG] Parent class <class 'simple_parsing.helpers.serialization.serializable.Serializable'> has decode_into_subclasses = False
# [2022-02-15 12:43:47,299][simple_parsing.helpers.serialization.serializable][DEBUG] Registering a new Serializable subclass: <class 'simple_parsing.helpers.hparams.hyperparameters.HyperParameters'>
# [2022-02-15 12:43:47,307][simple_parsing.helpers.serialization.serializable][DEBUG] Registering a new Serializable subclass: <class 'shared.schema.dataset.DatasetVersion'>
# [2022-02-15 12:43:47,308][simple_parsing.helpers.serialization.serializable][DEBUG] parents: [<class 'simple_parsing.helpers.serialization.serializable.Serializable'>, <class 'simple_parsing.helpers.serialization.serializable.SerializableMixin'>]
# [2022-02-15 12:43:47,309][simple_parsing.helpers.serialization.serializable][DEBUG] Parent class <class 'simple_parsing.helpers.serialization.serializable.Serializable'> has decode_into_subclasses = False
# [2022-02-15 12:43:47,311][simple_parsing.helpers.serialization.serializable][DEBUG] Registering a new Serializable subclass: <class 'shared.schema.dataset.DatasetSchema'>
# [2022-02-15 12:43:47,311][simple_parsing.helpers.serialization.serializable][DEBUG] parents: [<class 'shared.schema.dataset.DatasetPath'>, <class 'simple_parsing.helpers.serialization.serializable.Serializable'>, <class 'simple_parsing.helpers.serialization.serializable.SerializableMixin'>]
# [2022-02-15 12:43:47,312][simple_parsing.helpers.serialization.serializable][DEBUG] Parent class <class 'simple_parsing.helpers.serialization.serializable.Serializable'> has decode_into_subclasses = False
# [2022-02-15 12:43:47,337][simple_parsing.helpers.serialization.serializable][DEBUG] Registering a new Serializable subclass: <class 'shared.schema.graph.DType'>
# [2022-02-15 12:43:47,338][simple_parsing.helpers.serialization.serializable][DEBUG] parents: [<class 'simple_parsing.helpers.serialization.serializable.Serializable'>, <class 'simple_parsing.helpers.serialization.serializable.SerializableMixin'>]
# [2022-02-15 12:43:47,339][simple_parsing.helpers.serialization.serializable][DEBUG] Parent class <class 'simple_parsing.helpers.serialization.serializable.Serializable'> has decode_into_subclasses = False
# [2022-02-15 12:43:47,341][simple_parsing.helpers.serialization.serializable][DEBUG] Registering a new Serializable subclass: <class 'shared.schema.graph.GraphProperty'>
# [2022-02-15 12:43:47,342][simple_parsing.helpers.serialization.serializable][DEBUG] parents: [<class 'simple_parsing.helpers.serialization.serializable.Serializable'>, <class 'simple_parsing.helpers.serialization.serializable.SerializableMixin'>]
# [2022-02-15 12:43:47,343][simple_parsing.helpers.serialization.serializable][DEBUG] Parent class <class 'simple_parsing.helpers.serialization.serializable.Serializable'> has decode_into_subclasses = False
# [2022-02-15 12:43:47,344][simple_parsing.helpers.serialization.serializable][DEBUG] Registering a new Serializable subclass: <class 'shared.schema.graph.DynamicConfig'>
# [2022-02-15 12:43:47,345][simple_parsing.helpers.serialization.serializable][DEBUG] parents: [<class 'simple_parsing.helpers.serialization.serializable.Serializable'>, <class 'simple_parsing.helpers.serialization.serializable.SerializableMixin'>]
# [2022-02-15 12:43:47,345][simple_parsing.helpers.serialization.serializable][DEBUG] Parent class <class 'simple_parsing.helpers.serialization.serializable.Serializable'> has decode_into_subclasses = False
# [2022-02-15 12:43:47,349][simple_parsing.helpers.serialization.serializable][DEBUG] Registering a new Serializable subclass: <class 'shared.schema.graph.EntitySchema'>
# [2022-02-15 12:43:47,350][simple_parsing.helpers.serialization.serializable][DEBUG] parents: [<class 'simple_parsing.helpers.serialization.serializable.Serializable'>, <class 'simple_parsing.helpers.serialization.serializable.SerializableMixin'>]
# [2022-02-15 12:43:47,351][simple_parsing.helpers.serialization.serializable][DEBUG] Parent class <class 'simple_parsing.helpers.serialization.serializable.Serializable'> has decode_into_subclasses = False
# [2022-02-15 12:43:47,352][simple_parsing.helpers.serialization.serializable][DEBUG] Registering a new Serializable subclass: <class 'shared.schema.graph.NodeSchema'>
# [2022-02-15 12:43:47,353][simple_parsing.helpers.serialization.serializable][DEBUG] parents: [<class 'shared.schema.graph.EntitySchema'>, <class 'simple_parsing.helpers.serialization.serializable.Serializable'>, <class 'simple_parsing.helpers.serialization.serializable.SerializableMixin'>]
# [2022-02-15 12:43:47,354][simple_parsing.helpers.serialization.serializable][DEBUG] Parent class <class 'shared.schema.graph.EntitySchema'> has decode_into_subclasses = False
# [2022-02-15 12:43:47,355][simple_parsing.helpers.serialization.serializable][DEBUG] Registering a new Serializable subclass: <class 'shared.schema.graph.EdgeSchema'>
# [2022-02-15 12:43:47,356][simple_parsing.helpers.serialization.serializable][DEBUG] parents: [<class 'shared.schema.graph.EntitySchema'>, <class 'simple_parsing.helpers.serialization.serializable.Serializable'>, <class 'simple_parsing.helpers.serialization.serializable.SerializableMixin'>]
# [2022-02-15 12:43:47,357][simple_parsing.helpers.serialization.serializable][DEBUG] Parent class <class 'shared.schema.graph.EntitySchema'> has decode_into_subclasses = False
# [2022-02-15 12:43:47,358][simple_parsing.helpers.serialization.serializable][DEBUG] Registering a new Serializable subclass: <class 'shared.schema.graph.GraphSchema'>
# [2022-02-15 12:43:47,359][simple_parsing.helpers.serialization.serializable][DEBUG] parents: [<class 'simple_parsing.helpers.serialization.serializable.Serializable'>, <class 'simple_parsing.helpers.serialization.serializable.SerializableMixin'>]
# [2022-02-15 12:43:47,362][simple_parsing.helpers.serialization.serializable][DEBUG] Parent class <class 'simple_parsing.helpers.serialization.serializable.Serializable'> has decode_into_subclasses = False
# [2022-02-15 12:43:47,366][faiss.loader][INFO] Loading faiss with AVX2 support.
# [2022-02-15 12:43:47,367][faiss.loader][INFO] Could not load library with AVX2 support due to:
# ModuleNotFoundError("No module named 'faiss.swigfaiss_avx2'")
# [2022-02-15 12:43:47,368][faiss.loader][INFO] Loading faiss.
# [2022-02-15 12:43:47,384][faiss.loader][INFO] Successfully loaded faiss.

# %%
device = 'cpu'
experiment_name = 'pyg-n2v-experiment'
node_type = 'Character'
initialization = 'louvain'  # 'k-means' or 'none
repr_dim = 32
EPS = 1e-15
recluster = False
save_path = TMP_PATH.joinpath(experiment_name)
callbacks = [
    pl.callbacks.ModelSummary(),
    pl.callbacks.LearningRateMonitor(),
    pl.callbacks.EarlyStopping(monitor="val/loss", min_delta=0.00, patience=5, verbose=True, mode="min")
]

# %%
dataset = ml.StarWarsHomogenous()
transform = ToUndirected()
data = dataset[0]
G = dataset.G
G.to_undirected()
# Out:
# [2022-02-15 12:44:00,432][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.dataset.DatasetSchema'>, drop extra fields: True
# [2022-02-15 12:44:00,433][simple_parsing.helpers.serialization.decoding][DEBUG] name = name, field_type = <class 'str'>
# [2022-02-15 12:44:00,433][simple_parsing.helpers.serialization.decoding][DEBUG] name = database, field_type = <class 'str'>
# [2022-02-15 12:44:00,434][simple_parsing.helpers.serialization.decoding][DEBUG] name = description, field_type = <class 'str'>
# [2022-02-15 12:44:00,435][simple_parsing.helpers.serialization.decoding][DEBUG] name = versions, field_type = typing.Dict[str, shared.schema.dataset.DatasetVersion]
# [2022-02-15 12:44:00,435][simple_parsing.helpers.serialization.decoding][DEBUG] Decoding a Dict field: typing.Dict[str, shared.schema.dataset.DatasetVersion]
# [2022-02-15 12:44:00,436][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.dataset.DatasetVersion'>, drop extra fields: True
# [2022-02-15 12:44:00,437][simple_parsing.helpers.serialization.decoding][DEBUG] name = type, field_type = <enum 'DatasetVersionType'>
# [2022-02-15 12:44:00,437][simple_parsing.helpers.serialization.decoding][DEBUG] name = parameters, field_type = typing.Dict[str, typing.Any]
# [2022-02-15 12:44:00,438][simple_parsing.helpers.serialization.decoding][DEBUG] Decoding a Dict field: typing.Dict[str, typing.Any]
# [2022-02-15 12:44:00,438][simple_parsing.helpers.serialization.decoding][DEBUG] Decoding an Any type: typing.Any
# [2022-02-15 12:44:00,438][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.dataset.DatasetVersion'>, drop extra fields: True
# [2022-02-15 12:44:00,439][simple_parsing.helpers.serialization.decoding][DEBUG] name = type, field_type = <enum 'DatasetVersionType'>
# [2022-02-15 12:44:00,439][simple_parsing.helpers.serialization.decoding][DEBUG] name = parameters, field_type = typing.Dict[str, typing.Any]
# [2022-02-15 12:44:00,440][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.dataset.DatasetVersion'>, drop extra fields: True
# [2022-02-15 12:44:00,441][simple_parsing.helpers.serialization.decoding][DEBUG] name = type, field_type = <enum 'DatasetVersionType'>
# [2022-02-15 12:44:00,442][simple_parsing.helpers.serialization.decoding][DEBUG] name = parameters, field_type = typing.Dict[str, typing.Any]
# [2022-02-15 12:44:00,443][simple_parsing.helpers.serialization.decoding][DEBUG] name = tags, field_type = typing.List[str]
# [2022-02-15 12:44:00,444][simple_parsing.helpers.serialization.decoding][DEBUG] Decoding a List field: typing.List[str]
# [2022-02-15 12:44:00,466][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphSchema'>, drop extra fields: True
# [2022-02-15 12:44:00,467][simple_parsing.helpers.serialization.decoding][DEBUG] name = nodes, field_type = typing.Dict[str, shared.schema.graph.NodeSchema]
# [2022-02-15 12:44:00,468][simple_parsing.helpers.serialization.decoding][DEBUG] Decoding a Dict field: typing.Dict[str, shared.schema.graph.NodeSchema]
# [2022-02-15 12:44:00,469][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.NodeSchema'>, drop extra fields: True
# [2022-02-15 12:44:00,470][simple_parsing.helpers.serialization.decoding][DEBUG] name = label, field_type = <class 'str'>
# [2022-02-15 12:44:00,471][simple_parsing.helpers.serialization.decoding][DEBUG] name = properties, field_type = typing.Dict[str, shared.schema.graph.GraphProperty]
# [2022-02-15 12:44:00,472][simple_parsing.helpers.serialization.decoding][DEBUG] Decoding a Dict field: typing.Dict[str, shared.schema.graph.GraphProperty]
# [2022-02-15 12:44:00,473][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,474][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,475][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,476][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,477][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,478][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,479][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,480][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,481][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,482][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,483][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,484][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,485][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,486][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,487][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,488][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,489][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,489][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,490][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,493][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,493][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,494][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,494][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,495][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,495][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,496][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,496][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,496][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,497][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,497][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,498][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,498][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,499][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,499][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,499][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,500][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,501][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,503][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,505][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,506][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,507][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,507][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,508][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,509][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,510][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,511][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,512][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,513][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,514][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,515][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,516][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,517][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,518][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,518][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,519][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,520][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,521][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,522][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,523][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,524][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,525][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,526][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,527][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,527][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,528][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,529][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,530][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,531][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,532][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,533][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,533][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,534][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,535][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,536][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,546][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,547][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,548][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,548][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,549][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,550][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,551][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,551][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,552][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,553][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,554][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,555][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,556][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,557][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,558][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,559][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,560][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,560][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,561][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,562][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,563][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,563][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,564][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,565][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,566][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,566][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,567][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,568][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,568][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,569][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,569][simple_parsing.helpers.serialization.decoding][DEBUG] name = edges, field_type = typing.Dict[str, shared.schema.graph.EdgeSchema]
# [2022-02-15 12:44:00,573][simple_parsing.helpers.serialization.decoding][DEBUG] Decoding a Dict field: typing.Dict[str, shared.schema.graph.EdgeSchema]
# [2022-02-15 12:44:00,574][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.EdgeSchema'>, drop extra fields: True
# [2022-02-15 12:44:00,574][simple_parsing.helpers.serialization.decoding][DEBUG] name = properties, field_type = typing.Dict[str, shared.schema.graph.GraphProperty]
# [2022-02-15 12:44:00,574][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,575][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,575][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,576][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,576][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,576][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,577][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,577][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,577][simple_parsing.helpers.serialization.decoding][DEBUG] name = dynamic, field_type = typing.Optional[shared.schema.graph.DynamicConfig]
# [2022-02-15 12:44:00,578][simple_parsing.helpers.serialization.decoding][DEBUG] Decoding a Union field: typing.Optional[shared.schema.graph.DynamicConfig]
# [2022-02-15 12:44:00,578][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.DynamicConfig'>, drop extra fields: True
# [2022-02-15 12:44:00,579][simple_parsing.helpers.serialization.decoding][DEBUG] name = timestamp, field_type = <class 'str'>
# [2022-02-15 12:44:00,579][simple_parsing.helpers.serialization.decoding][DEBUG] name = interaction, field_type = <class 'bool'>
# [2022-02-15 12:44:00,579][simple_parsing.helpers.serialization.decoding][DEBUG] name = source_type, field_type = <class 'str'>
# [2022-02-15 12:44:00,580][simple_parsing.helpers.serialization.decoding][DEBUG] name = target_type, field_type = <class 'str'>
# [2022-02-15 12:44:00,580][simple_parsing.helpers.serialization.decoding][DEBUG] name = directed, field_type = <class 'bool'>
# [2022-02-15 12:44:00,580][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.EdgeSchema'>, drop extra fields: True
# [2022-02-15 12:44:00,581][simple_parsing.helpers.serialization.decoding][DEBUG] name = properties, field_type = typing.Dict[str, shared.schema.graph.GraphProperty]
# [2022-02-15 12:44:00,581][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,581][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,582][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,582][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,582][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,583][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,583][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:44:00,584][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:44:00,584][simple_parsing.helpers.serialization.decoding][DEBUG] name = dynamic, field_type = typing.Optional[shared.schema.graph.DynamicConfig]
# [2022-02-15 12:44:00,584][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.DynamicConfig'>, drop extra fields: True
# [2022-02-15 12:44:00,585][simple_parsing.helpers.serialization.decoding][DEBUG] name = timestamp, field_type = <class 'str'>
# [2022-02-15 12:44:00,585][simple_parsing.helpers.serialization.decoding][DEBUG] name = interaction, field_type = <class 'bool'>
# [2022-02-15 12:44:00,585][simple_parsing.helpers.serialization.decoding][DEBUG] name = source_type, field_type = <class 'str'>
# [2022-02-15 12:44:00,586][simple_parsing.helpers.serialization.decoding][DEBUG] name = target_type, field_type = <class 'str'>
# [2022-02-15 12:44:00,586][simple_parsing.helpers.serialization.decoding][DEBUG] name = directed, field_type = <class 'bool'>

# %%
edge_index = data.edge_stores[0].edge_index
edge_index = torch.cat([
    edge_index,
    torch.stack([edge_index[1, :], edge_index[0, :]])
], dim=1)
row, col = edge_index

csr = csr_matrix(
    (torch.ones(edge_index.shape[1], dtype=torch.int32).numpy(), (row.numpy(), col.numpy())),
    shape=(data.num_nodes, data.num_nodes),
)
neg_neighbors = [
    list(set(range(data.num_nodes)).difference(set(csr[i, :].indices)))
    for i in range(data.num_nodes)
]

# %%
def neg_sample(batch: torch.Tensor, num_neg_samples: int = 1) -> torch.Tensor:
    result = torch.tensor([
        random.choices(neg_neighbors[i], k=num_neg_samples)
        for i in batch[:, 0]
    ], dtype=torch.long)
    return result


repeat_count = 2
num_neg_samples = 3
pos_idx = edge_index.t().repeat(repeat_count, 1)
neg_idx = neg_sample(pos_idx, num_neg_samples=num_neg_samples)
data_idx = torch.cat([pos_idx, neg_idx], dim=1)

node_loader = NeighborLoader(
    data=data, num_neighbors=[4, 4], input_nodes='Character', directed=False, replace=False
)

# %%
class SamplesLoader(BaseDataLoader):
    def __init__(
            self,
            data,
            **kwargs
    ):
        self.node_loader = node_loader

        super().__init__(
            data.tolist(),
            collate_fn=self.sample,
            **kwargs,
        )

    def sample(self, indices):
        indices = torch.tensor(indices, dtype=torch.long).view(-1).tolist()
        return self.node_loader.neighbor_sampler(indices)

    def transform_fn(self, out):
        return self.node_loader.transform_fn(out)


data_loader = SamplesLoader(data_idx, batch_size=8, shuffle=True)
next(iter(data_loader))
# Out:
# HeteroData(
#   Character={
#     x=[67, 32],
#     batch_size=40
#   },
#   (Character, INTERACTIONS, Character)={
#     edge_attr=[486, 0],
#     edge_index=[2, 486],
#     timestamp=[486]
#   }
# )

# %%
embedding_module = experiments.GraphSAGEModule(node_type, data.metadata(), repr_dim, n_layers=2)
model = embedding_module
optimizer = torch.optim.Adam(list(model.parameters()), lr=0.01)

cos_sim = torch.nn.CosineSimilarity(dim=2)

def train():
    model.train()
    total_loss = 0
    for batch in data_loader:
        optimizer.zero_grad()

        emb = embedding_module(batch)
        neg_pos_emb = emb.view(-1, num_neg_samples + 2, repr_dim)
        ctr_emb = neg_pos_emb[:, 0, :].unsqueeze(1)
        pos_emb = neg_pos_emb[:, 1, :].unsqueeze(1)
        neg_emb = neg_pos_emb[:, 2:, :]

        out = cos_sim(ctr_emb, pos_emb).view(-1)
        pos_loss = -torch.log(torch.sigmoid(out) + EPS).mean()

        out = cos_sim(ctr_emb, neg_emb).view(-1)
        neg_loss = -torch.log(1 - torch.sigmoid(out) + EPS).mean()

        loss = pos_loss + neg_loss
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    return total_loss / len(data_loader)

def get_embeddings():
    model.eval()
    embs = []
    for batch in node_loader:
        emb = embedding_module(batch)
        embs.append(emb)

    return torch.cat(embs, dim=0)


for epoch in range(1, 20):
    loss = train()
    # acc = test()
    acc = np.nan
    print(f'Epoch: {epoch:02d}, Loss: {loss:.4f}, Acc: {acc:.4f}')  #
# Out:
# Epoch: 01, Loss: 1.1415, Acc: nan
# Epoch: 02, Loss: 1.0982, Acc: nan
# Epoch: 03, Loss: 1.0905, Acc: nan
# Epoch: 04, Loss: 1.0851, Acc: nan
# Epoch: 05, Loss: 1.0814, Acc: nan
# Epoch: 06, Loss: 1.0789, Acc: nan
# Epoch: 07, Loss: 1.0766, Acc: nan
# Epoch: 08, Loss: 1.0780, Acc: nan
# Epoch: 09, Loss: 1.0752, Acc: nan
# Epoch: 10, Loss: 1.0729, Acc: nan
# Epoch: 11, Loss: 1.0745, Acc: nan
# Epoch: 12, Loss: 1.0726, Acc: nan
# Epoch: 13, Loss: 1.0729, Acc: nan
# Epoch: 14, Loss: 1.0711, Acc: nan
# Epoch: 15, Loss: 1.0717, Acc: nan
# Epoch: 16, Loss: 1.0702, Acc: nan
# Epoch: 17, Loss: 1.0705, Acc: nan
# Epoch: 18, Loss: 1.0704, Acc: nan
# Epoch: 19, Loss: 1.0698, Acc: nan

# %%
from shared.constants import BENCHMARKS_RESULTS
import faiss
import pandas as pd

save_path = BENCHMARKS_RESULTS.joinpath('analysis', experiment_name)
save_path.mkdir(parents=True, exist_ok=True)

# %%
embeddings = get_embeddings().detach()

# Normalize for cosine similarity
embeddings = embeddings / torch.norm(embeddings, dim=1, keepdim=True)

k = 5
kmeans = faiss.Kmeans(embeddings.shape[1], k, niter=20, verbose=True, nredo=10)
kmeans.train(embeddings.numpy())
D, I = kmeans.index.search(embeddings.numpy(), 1)
# Out:
# Clustering 113 points in 32D to 5 clusters, redo 10 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 10
#   Iteration 19 (0.00 s, search 0.00 s): objective=28.6359 imbalance=1.145 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 10
#   Iteration 19 (0.00 s, search 0.00 s): objective=28.6359 imbalance=1.145 nsplit=0
# Outer iteration 2 / 10
#   Iteration 19 (0.01 s, search 0.00 s): objective=25.6957 imbalance=1.181 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 10
#   Iteration 19 (0.01 s, search 0.01 s): objective=25.3886 imbalance=1.076 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 10
#   Iteration 19 (0.01 s, search 0.01 s): objective=25.2893 imbalance=1.090 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 5 / 10
#   Iteration 19 (0.01 s, search 0.01 s): objective=26.1573 imbalance=1.184 nsplit=0
# Outer iteration 6 / 10
#   Iteration 19 (0.01 s, search 0.01 s): objective=24.6243 imbalance=1.110 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 7 / 10
#   Iteration 19 (0.01 s, search 0.01 s): objective=24.5771 imbalance=1.124 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 8 / 10
#   Iteration 19 (0.02 s, search 0.01 s): objective=27.5203 imbalance=1.121 nsplit=0
# Outer iteration 9 / 10
#   Iteration 19 (0.02 s, search 0.01 s): objective=24.7729 imbalance=1.100 nsplit=0
# WARNING clustering 113 points to 5 centroids: please provide at least 195 training points

# %%
from shared.graph import CommunityAssignment

labeling = pd.Series(I.squeeze(), index=dataset.node_mapping(), name="cid")
labeling.index.name = "nid"
comlist = CommunityAssignment(labeling)
comlist.save_comlist(save_path.joinpath('schema.comlist'))

# %%
from datasets.scripts import export_to_visualization
from shared.graph import DataGraph
from benchmarks.evaluation import get_metric_list
from shared.schema import GraphSchema, DatasetSchema

export_to_visualization.run(
    export_to_visualization.Args(
        dataset='star-wars',
        version='base',
        run_paths=[str(save_path)]
    )
)
# Out:
# [2022-02-15 12:46:13,315][simple_parsing.helpers.serialization.serializable][DEBUG] Registering a new Serializable subclass: <class 'benchmarks.config.TunedParameterValue'>
# [2022-02-15 12:46:13,316][simple_parsing.helpers.serialization.serializable][DEBUG] parents: [<class 'simple_parsing.helpers.serialization.serializable.Serializable'>, <class 'simple_parsing.helpers.serialization.serializable.SerializableMixin'>]
# [2022-02-15 12:46:13,317][simple_parsing.helpers.serialization.serializable][DEBUG] Parent class <class 'simple_parsing.helpers.serialization.serializable.Serializable'> has decode_into_subclasses = False
# [2022-02-15 12:46:13,318][simple_parsing.helpers.serialization.serializable][DEBUG] Registering a new Serializable subclass: <class 'benchmarks.config.ParameterConfig'>
# [2022-02-15 12:46:13,319][simple_parsing.helpers.serialization.serializable][DEBUG] parents: [<class 'dict'>, <class 'simple_parsing.helpers.serialization.serializable.Serializable'>, <class 'simple_parsing.helpers.serialization.serializable.SerializableMixin'>]
# [2022-02-15 12:46:13,320][simple_parsing.helpers.serialization.serializable][DEBUG] Parent class <class 'simple_parsing.helpers.serialization.serializable.Serializable'> has decode_into_subclasses = False
# [2022-02-15 12:46:13,321][simple_parsing.helpers.serialization.serializable][DEBUG] Registering a new Serializable subclass: <class 'benchmarks.config.ExecutionConfig'>
# [2022-02-15 12:46:13,321][simple_parsing.helpers.serialization.serializable][DEBUG] parents: [<class 'simple_parsing.helpers.serialization.serializable.Serializable'>, <class 'simple_parsing.helpers.serialization.serializable.SerializableMixin'>]
# [2022-02-15 12:46:13,322][simple_parsing.helpers.serialization.serializable][DEBUG] Parent class <class 'simple_parsing.helpers.serialization.serializable.Serializable'> has decode_into_subclasses = False
# [2022-02-15 12:46:13,324][simple_parsing.helpers.serialization.serializable][DEBUG] Registering a new Serializable subclass: <class 'benchmarks.config.DatasetRunConfig'>
# [2022-02-15 12:46:13,324][simple_parsing.helpers.serialization.serializable][DEBUG] parents: [<class 'simple_parsing.helpers.serialization.serializable.Serializable'>, <class 'simple_parsing.helpers.serialization.serializable.SerializableMixin'>]
# [2022-02-15 12:46:13,325][simple_parsing.helpers.serialization.serializable][DEBUG] Parent class <class 'simple_parsing.helpers.serialization.serializable.Serializable'> has decode_into_subclasses = False
# [2022-02-15 12:46:13,326][simple_parsing.helpers.serialization.serializable][DEBUG] Registering a new Serializable subclass: <class 'benchmarks.config.BenchmarkConfig'>
# [2022-02-15 12:46:13,327][simple_parsing.helpers.serialization.serializable][DEBUG] parents: [<class 'simple_parsing.helpers.serialization.serializable.Serializable'>, <class 'simple_parsing.helpers.serialization.serializable.SerializableMixin'>]
# [2022-02-15 12:46:13,328][simple_parsing.helpers.serialization.serializable][DEBUG] Parent class <class 'simple_parsing.helpers.serialization.serializable.Serializable'> has decode_into_subclasses = False
# [2022-02-15 12:46:13,339][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.dataset.DatasetSchema'>, drop extra fields: True
# [2022-02-15 12:46:13,340][simple_parsing.helpers.serialization.decoding][DEBUG] name = name, field_type = <class 'str'>
# [2022-02-15 12:46:13,341][simple_parsing.helpers.serialization.decoding][DEBUG] name = database, field_type = <class 'str'>
# [2022-02-15 12:46:13,342][simple_parsing.helpers.serialization.decoding][DEBUG] name = description, field_type = <class 'str'>
# [2022-02-15 12:46:13,342][simple_parsing.helpers.serialization.decoding][DEBUG] name = versions, field_type = typing.Dict[str, shared.schema.dataset.DatasetVersion]
# [2022-02-15 12:46:13,343][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.dataset.DatasetVersion'>, drop extra fields: True
# [2022-02-15 12:46:13,344][simple_parsing.helpers.serialization.decoding][DEBUG] name = type, field_type = <enum 'DatasetVersionType'>
# [2022-02-15 12:46:13,345][simple_parsing.helpers.serialization.decoding][DEBUG] name = parameters, field_type = typing.Dict[str, typing.Any]
# [2022-02-15 12:46:13,346][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.dataset.DatasetVersion'>, drop extra fields: True
# [2022-02-15 12:46:13,346][simple_parsing.helpers.serialization.decoding][DEBUG] name = type, field_type = <enum 'DatasetVersionType'>
# [2022-02-15 12:46:13,347][simple_parsing.helpers.serialization.decoding][DEBUG] name = parameters, field_type = typing.Dict[str, typing.Any]
# [2022-02-15 12:46:13,348][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.dataset.DatasetVersion'>, drop extra fields: True
# [2022-02-15 12:46:13,349][simple_parsing.helpers.serialization.decoding][DEBUG] name = type, field_type = <enum 'DatasetVersionType'>
# [2022-02-15 12:46:13,353][simple_parsing.helpers.serialization.decoding][DEBUG] name = parameters, field_type = typing.Dict[str, typing.Any]
# [2022-02-15 12:46:13,354][simple_parsing.helpers.serialization.decoding][DEBUG] name = tags, field_type = typing.List[str]
# [2022-02-15 12:46:13,355][export_to_visualization.py][INFO] Processing /data/pella/projects/University/Thesis/Thesis/code/storage/datasets/processed/star-wars/schema.yaml
# [2022-02-15 12:46:13,390][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphSchema'>, drop extra fields: True
# [2022-02-15 12:46:13,391][simple_parsing.helpers.serialization.decoding][DEBUG] name = nodes, field_type = typing.Dict[str, shared.schema.graph.NodeSchema]
# [2022-02-15 12:46:13,392][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.NodeSchema'>, drop extra fields: True
# [2022-02-15 12:46:13,393][simple_parsing.helpers.serialization.decoding][DEBUG] name = label, field_type = <class 'str'>
# [2022-02-15 12:46:13,394][simple_parsing.helpers.serialization.decoding][DEBUG] name = properties, field_type = typing.Dict[str, shared.schema.graph.GraphProperty]
# [2022-02-15 12:46:13,394][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,395][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,396][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,397][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,398][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,399][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,399][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,400][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,401][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,402][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,403][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,404][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,404][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,405][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,406][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,407][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,408][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,409][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,409][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,410][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,411][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,412][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,413][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,413][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,414][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,415][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,416][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,417][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,418][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,419][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,419][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,429][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,430][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,430][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,431][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,432][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,433][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,434][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,435][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,435][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,436][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,437][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,438][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,439][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,439][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,440][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,441][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,445][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,445][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,446][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,446][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,446][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,447][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,447][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,448][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,448][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,448][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,449][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,449][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,450][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,450][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,451][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,451][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,451][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,452][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,452][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,453][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,453][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,453][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,454][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,454][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,455][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,455][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,455][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,456][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,456][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,457][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,461][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,461][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,462][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,462][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,463][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,463][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,463][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,464][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,464][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,465][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,465][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,466][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,466][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,466][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,467][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,467][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,468][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,468][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,469][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,469][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,469][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,470][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,470][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,471][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,471][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,471][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,472][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,472][simple_parsing.helpers.serialization.decoding][DEBUG] name = edges, field_type = typing.Dict[str, shared.schema.graph.EdgeSchema]
# [2022-02-15 12:46:13,473][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.EdgeSchema'>, drop extra fields: True
# [2022-02-15 12:46:13,473][simple_parsing.helpers.serialization.decoding][DEBUG] name = properties, field_type = typing.Dict[str, shared.schema.graph.GraphProperty]
# [2022-02-15 12:46:13,473][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,474][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,474][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,475][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,475][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,475][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,476][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,476][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,477][simple_parsing.helpers.serialization.decoding][DEBUG] name = dynamic, field_type = typing.Optional[shared.schema.graph.DynamicConfig]
# [2022-02-15 12:46:13,477][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.DynamicConfig'>, drop extra fields: True
# [2022-02-15 12:46:13,478][simple_parsing.helpers.serialization.decoding][DEBUG] name = timestamp, field_type = <class 'str'>
# [2022-02-15 12:46:13,478][simple_parsing.helpers.serialization.decoding][DEBUG] name = interaction, field_type = <class 'bool'>
# [2022-02-15 12:46:13,478][simple_parsing.helpers.serialization.decoding][DEBUG] name = source_type, field_type = <class 'str'>
# [2022-02-15 12:46:13,479][simple_parsing.helpers.serialization.decoding][DEBUG] name = target_type, field_type = <class 'str'>
# [2022-02-15 12:46:13,479][simple_parsing.helpers.serialization.decoding][DEBUG] name = directed, field_type = <class 'bool'>
# [2022-02-15 12:46:13,480][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.EdgeSchema'>, drop extra fields: True
# [2022-02-15 12:46:13,480][simple_parsing.helpers.serialization.decoding][DEBUG] name = properties, field_type = typing.Dict[str, shared.schema.graph.GraphProperty]
# [2022-02-15 12:46:13,480][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,481][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,481][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,482][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,482][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,482][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,483][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:13,483][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:13,484][simple_parsing.helpers.serialization.decoding][DEBUG] name = dynamic, field_type = typing.Optional[shared.schema.graph.DynamicConfig]
# [2022-02-15 12:46:13,484][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.DynamicConfig'>, drop extra fields: True
# [2022-02-15 12:46:13,484][simple_parsing.helpers.serialization.decoding][DEBUG] name = timestamp, field_type = <class 'str'>
# [2022-02-15 12:46:13,485][simple_parsing.helpers.serialization.decoding][DEBUG] name = interaction, field_type = <class 'bool'>
# [2022-02-15 12:46:13,485][simple_parsing.helpers.serialization.decoding][DEBUG] name = source_type, field_type = <class 'str'>
# [2022-02-15 12:46:13,486][simple_parsing.helpers.serialization.decoding][DEBUG] name = target_type, field_type = <class 'str'>
# [2022-02-15 12:46:13,486][simple_parsing.helpers.serialization.decoding][DEBUG] name = directed, field_type = <class 'bool'>
# [2022-02-15 12:46:13,559][export_to_visualization.py][INFO] Adding prediction /data/pella/projects/University/Thesis/Thesis/code/storage/results/analysis/pyg-n2v-experiment/schema.comlist as prediction_0
# [2022-02-15 12:46:13,568][export_to_visualization.py][INFO] Writing /data/pella/projects/University/Thesis/Thesis/code/storage/datasets/export/star-wars/versions/base/schema.graphml

# %%
DATASET = DatasetSchema.load_schema('star-wars')
schema = GraphSchema.from_dataset(DATASET)
G = DataGraph.from_schema(schema)
G.to_undirected()

metrics = get_metric_list(ground_truth=False, overlapping=False)
results = pd.DataFrame([
    {
        'metric': metric_cls.metric_name(),
        'value': metric_cls.calculate(G, comlist)
    }
    for metric_cls in metrics]
)
results
# Out:
# [2022-02-15 12:46:29,881][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.dataset.DatasetSchema'>, drop extra fields: True
# [2022-02-15 12:46:29,882][simple_parsing.helpers.serialization.decoding][DEBUG] name = name, field_type = <class 'str'>
# [2022-02-15 12:46:29,883][simple_parsing.helpers.serialization.decoding][DEBUG] name = database, field_type = <class 'str'>
# [2022-02-15 12:46:29,884][simple_parsing.helpers.serialization.decoding][DEBUG] name = description, field_type = <class 'str'>
# [2022-02-15 12:46:29,885][simple_parsing.helpers.serialization.decoding][DEBUG] name = versions, field_type = typing.Dict[str, shared.schema.dataset.DatasetVersion]
# [2022-02-15 12:46:29,885][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.dataset.DatasetVersion'>, drop extra fields: True
# [2022-02-15 12:46:29,886][simple_parsing.helpers.serialization.decoding][DEBUG] name = type, field_type = <enum 'DatasetVersionType'>
# [2022-02-15 12:46:29,887][simple_parsing.helpers.serialization.decoding][DEBUG] name = parameters, field_type = typing.Dict[str, typing.Any]
# [2022-02-15 12:46:29,887][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.dataset.DatasetVersion'>, drop extra fields: True
# [2022-02-15 12:46:29,888][simple_parsing.helpers.serialization.decoding][DEBUG] name = type, field_type = <enum 'DatasetVersionType'>
# [2022-02-15 12:46:29,889][simple_parsing.helpers.serialization.decoding][DEBUG] name = parameters, field_type = typing.Dict[str, typing.Any]
# [2022-02-15 12:46:29,889][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.dataset.DatasetVersion'>, drop extra fields: True
# [2022-02-15 12:46:29,890][simple_parsing.helpers.serialization.decoding][DEBUG] name = type, field_type = <enum 'DatasetVersionType'>
# [2022-02-15 12:46:29,890][simple_parsing.helpers.serialization.decoding][DEBUG] name = parameters, field_type = typing.Dict[str, typing.Any]
# [2022-02-15 12:46:29,891][simple_parsing.helpers.serialization.decoding][DEBUG] name = tags, field_type = typing.List[str]
# [2022-02-15 12:46:29,925][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphSchema'>, drop extra fields: True
# [2022-02-15 12:46:29,926][simple_parsing.helpers.serialization.decoding][DEBUG] name = nodes, field_type = typing.Dict[str, shared.schema.graph.NodeSchema]
# [2022-02-15 12:46:29,926][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.NodeSchema'>, drop extra fields: True
# [2022-02-15 12:46:29,927][simple_parsing.helpers.serialization.decoding][DEBUG] name = label, field_type = <class 'str'>
# [2022-02-15 12:46:29,927][simple_parsing.helpers.serialization.decoding][DEBUG] name = properties, field_type = typing.Dict[str, shared.schema.graph.GraphProperty]
# [2022-02-15 12:46:29,927][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,928][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,928][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,928][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,929][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,929][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,930][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,931][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,932][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,932][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,933][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,934][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,934][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,935][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,936][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,936][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,937][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,938][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,938][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,942][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,943][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,944][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,944][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,945][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,945][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,946][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,946][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,947][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,948][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,948][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,949][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,950][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,950][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,951][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,952][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,952][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,953][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,954][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,954][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,955][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,955][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,956][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,957][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,957][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,958][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,958][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,959][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,960][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,966][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,967][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,968][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,969][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,970][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,971][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,972][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,973][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,974][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,975][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,976][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,976][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,977][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,978][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,979][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,979][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,980][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,981][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,982][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,983][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,983][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,984][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,985][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,985][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,986][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,987][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,988][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,989][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,989][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,990][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,991][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,992][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,992][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,993][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,994][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,995][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,995][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,996][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,997][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:29,998][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:29,999][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:30,000][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:30,001][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:30,002][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:30,004][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:30,005][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:30,006][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:30,007][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:30,008][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:30,009][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:30,010][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:30,012][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:30,013][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:30,014][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:30,014][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:30,015][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:30,015][simple_parsing.helpers.serialization.decoding][DEBUG] name = edges, field_type = typing.Dict[str, shared.schema.graph.EdgeSchema]
# [2022-02-15 12:46:30,016][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.EdgeSchema'>, drop extra fields: True
# [2022-02-15 12:46:30,016][simple_parsing.helpers.serialization.decoding][DEBUG] name = properties, field_type = typing.Dict[str, shared.schema.graph.GraphProperty]
# [2022-02-15 12:46:30,017][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:30,017][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:30,018][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:30,018][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:30,019][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:30,019][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:30,019][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:30,020][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:30,020][simple_parsing.helpers.serialization.decoding][DEBUG] name = dynamic, field_type = typing.Optional[shared.schema.graph.DynamicConfig]
# [2022-02-15 12:46:30,021][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.DynamicConfig'>, drop extra fields: True
# [2022-02-15 12:46:30,021][simple_parsing.helpers.serialization.decoding][DEBUG] name = timestamp, field_type = <class 'str'>
# [2022-02-15 12:46:30,022][simple_parsing.helpers.serialization.decoding][DEBUG] name = interaction, field_type = <class 'bool'>
# [2022-02-15 12:46:30,022][simple_parsing.helpers.serialization.decoding][DEBUG] name = source_type, field_type = <class 'str'>
# [2022-02-15 12:46:30,023][simple_parsing.helpers.serialization.decoding][DEBUG] name = target_type, field_type = <class 'str'>
# [2022-02-15 12:46:30,023][simple_parsing.helpers.serialization.decoding][DEBUG] name = directed, field_type = <class 'bool'>
# [2022-02-15 12:46:30,023][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.EdgeSchema'>, drop extra fields: True
# [2022-02-15 12:46:30,024][simple_parsing.helpers.serialization.decoding][DEBUG] name = properties, field_type = typing.Dict[str, shared.schema.graph.GraphProperty]
# [2022-02-15 12:46:30,024][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:30,025][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:30,025][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:30,026][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:30,026][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:30,026][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:30,027][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.GraphProperty'>, drop extra fields: True
# [2022-02-15 12:46:30,027][simple_parsing.helpers.serialization.decoding][DEBUG] name = dtype, field_type = <class 'shared.schema.graph.DType'>
# [2022-02-15 12:46:30,028][simple_parsing.helpers.serialization.decoding][DEBUG] name = dynamic, field_type = typing.Optional[shared.schema.graph.DynamicConfig]
# [2022-02-15 12:46:30,028][simple_parsing.helpers.serialization.serializable][DEBUG] from_dict for <class 'shared.schema.graph.DynamicConfig'>, drop extra fields: True
# [2022-02-15 12:46:30,028][simple_parsing.helpers.serialization.decoding][DEBUG] name = timestamp, field_type = <class 'str'>
# [2022-02-15 12:46:30,029][simple_parsing.helpers.serialization.decoding][DEBUG] name = interaction, field_type = <class 'bool'>
# [2022-02-15 12:46:30,029][simple_parsing.helpers.serialization.decoding][DEBUG] name = source_type, field_type = <class 'str'>
# [2022-02-15 12:46:30,030][simple_parsing.helpers.serialization.decoding][DEBUG] name = target_type, field_type = <class 'str'>
# [2022-02-15 12:46:30,030][simple_parsing.helpers.serialization.decoding][DEBUG] name = directed, field_type = <class 'bool'>
#                   metric     value
# 0        community_count       NaN
# 1            conductance  0.560363
# 2              expansion  6.364586
# 3  internal_edge_density  0.309625
# 4                avg_odf  6.364586
# 5     modularity_overlap  0.038812
# 6        link_modularity  0.082726
# 7           z_modularity  0.533332
# 8             modularity  0.249470
