# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pyspark.sql.functions as F
import pyspark.sql.types as T
from pyspark.sql import SparkSession

# %%
spark = (SparkSession.builder
         .appName('Import sw data')
         .config('spark.sql.legacy.timeParserPolicy', 'LEGACY')
         .config("spark.executor.memory", "8g")
         .config("spark.driver.memory", "8g")
         .config("spark.memory.offHeap.enabled", True)
         .config("spark.memory.offHeap.size", "16g")
         .config("spark.jars.packages", "com.databricks:spark-xml_2.12:0.13.0,org.mongodb.spark:mongo-spark-connector_2.12:3.0.1")
         .config("spark.mongodb.output.uri", "mongodb://root:helloworld@127.0.0.1/wiki.starwars?authSource=admin")
         .getOrCreate())
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/data/pella/projects/University/Thesis/Thesis/code/env/lib/python3.9/site-packages/pyspark/jars/spark-unsafe_2.12-3.2.0.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# :: loading settings :: url = jar:file:/data/pella/projects/University/Thesis/Thesis/code/env/lib/python3.9/site-packages/pyspark/jars/ivy-2.5.0.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/egordm/.ivy2/cache
# The jars for the packages stored in: /home/egordm/.ivy2/jars
# com.databricks#spark-xml_2.12 added as a dependency
# org.mongodb.spark#mongo-spark-connector_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-001b6935-c59b-4590-a282-19cf632eac94;1.0
# 	confs: [default]
# 	found com.databricks#spark-xml_2.12;0.13.0 in central
# 	found commons-io#commons-io;2.8.0 in central
# 	found org.glassfish.jaxb#txw2;2.3.4 in central
# 	found org.apache.ws.xmlschema#xmlschema-core;2.2.5 in central
# 	found org.mongodb.spark#mongo-spark-connector_2.12;3.0.1 in central
# 	found org.mongodb#mongodb-driver-sync;4.0.5 in central
# 	found org.mongodb#bson;4.0.5 in central
# 	found org.mongodb#mongodb-driver-core;4.0.5 in central
# :: resolution report :: resolve 299ms :: artifacts dl 14ms
# 	:: modules in use:
# 	com.databricks#spark-xml_2.12;0.13.0 from central in [default]
# 	commons-io#commons-io;2.8.0 from central in [default]
# 	org.apache.ws.xmlschema#xmlschema-core;2.2.5 from central in [default]
# 	org.glassfish.jaxb#txw2;2.3.4 from central in [default]
# 	org.mongodb#bson;4.0.5 from central in [default]
# 	org.mongodb#mongodb-driver-core;4.0.5 from central in [default]
# 	org.mongodb#mongodb-driver-sync;4.0.5 from central in [default]
# 	org.mongodb.spark#mongo-spark-connector_2.12;3.0.1 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   8   |   0   |   0   |   0   ||   8   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-001b6935-c59b-4590-a282-19cf632eac94
# 	confs: [default]
# 	0 artifacts copied, 8 already retrieved (0kB/10ms)
# 22/02/03 21:26:20 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
df = (
    spark.read.format('xml')
        .option("rowTag", "page")
        .load("/data/pella/projects/University/Thesis/Thesis/code/storage/datasets/raw/star-wars/starwars_pages_current.xml")
).cache()

# %%
df.head(5)
# Out:
# [Row(id=1, ns=6, redirect=None, restrictions=None, revision=Row(comment=None, contributor=Row(id=116899, ip=None, username='Imperators II'), format='text/x-wiki', id=10712747, minor=None, model='wikitext', parentid=10210213, sha1='t4x8ueo47t5vq1fou4wiux1p0a39o76', text=Row(_VALUE='{{Top|fprot|uprot}}\n==Summary==\n{{Information\n|attention=\n|description=The logo of [[Wookieepedia]]. Cropped and modified from a picture of the [[Death Star II/Legends|second Death Star]].\n|source=Take a guess.\n|artist=*[[Tracy Duncan]] provided original design\n*[[User:Jaden Kenobi|Tyber]] provided higher-resolution version\n|filespecs=\n|licensing={{GFDL}}\n{{Cc-by-sa|3.0}}\n|other versions=[[:File:Wiki-shrinkable.png]]\n|cat artist=skip\n|cat licensee=skip\n|cat subject=skip\n|cat type=[[Category:Wookieepedia icons]]\n}}', _bytes=519, _xml:space='preserve'), timestamp=datetime.datetime(2021, 8, 15, 11, 26, 12)), title='File:Wiki.png'),
#  Row(id=2, ns=2, redirect=None, restrictions=None, revision=Row(comment='@import', contributor=Row(id=285, ip=None, username='LouCypher'), format='text/css', id=202900, minor=None, model='css', parentid=None, sha1='kqstuzaobar4w3mxn6a4b1xyw9r5bhn', text=Row(_VALUE='@import url("http://www.wikicities.com/index.php?title=User:LouCypher/monobook.css&action=raw&ctype=text/css");', _bytes=111, _xml:space='preserve'), timestamp=datetime.datetime(2005, 3, 4, 23, 33, 55)), title='User:LouCypher/monobook.css'),
#  Row(id=4, ns=10, redirect=None, restrictions=None, revision=Row(comment='Dark mode fix', contributor=Row(id=40174461, ip=None, username='TOM-E Macaron.ii'), format='text/x-wiki', id=10578083, minor='', model='wikitext', parentid=10411167, sha1='8960cmztpbfttjd5y9v5x9cguwj5x8s', text=Row(_VALUE='{| id="gfdl" class="darkbackground1 messagebox noprint" align="center" border="0" cellpadding="4" cellspacing="4" style="border: 1px solid #CC9; background-color: #F1F1DE"\n|-\n| [[File:Heckert_gnu.svg|70px|center|]]\n| Permission is granted to copy, distribute and/or modify this image under the terms of the [[w:Community Central:Text of the GNU Free Documentation License|GNU Free Documentation License]], Version 1.2 or any later version published by the Free Software Foundation; with no Invariant Sections, no Front-Cover Texts, and no Back-Cover Texts. Subject to [[w:Community Central:Disclaimers|Fandom disclaimers]].\n|}<includeonly>{{SpecialCategorizer|[[Category:GFDL images|{{PAGENAME}}]]}}</includeonly><noinclude>\n\n==Categorization==\n*[[:Category:GFDL images]]\n\n[[Category:Copyright templates|{{PAGENAME}}]]</noinclude>', _bytes=830, _xml:space='preserve'), timestamp=datetime.datetime(2021, 6, 29, 12, 12, 16)), title='Template:GFDL'),
#  Row(id=5, ns=0, redirect=None, restrictions=None, revision=Row(comment='Fixing file extensions', contributor=Row(id=24541515, ip=None, username='RoboCade'), format='text/x-wiki', id=11084657, minor='', model='wikitext', parentid=11018227, sha1='ljqh8bqlyl908mgvsttwikhw0k1am8n', text=Row(_VALUE='{{Top|ffa|leg}}\n{{Youmay|the [[Echani/Legends|Echani]] [[Hybrid/Legends|hybrid]]|the [[Brianna (Human)|Human]]}}\n{{Character\n|type=Jedi\n|image=[[File:Handmaidenpromo.jpg]]\n|name=Brianna\n|homeworld=\n|birth=[[3976 BBY]]<ref name="age">{{Cite_web|url=http://forums.obsidianent.com/index.php?showtopic=25061&st=0&p=184142&#entry184142|title=Age of the Characters|date=2004-11-11|work=Obsidian Entertainment forums|archiveurl=https://web.archive.org/web/20170720114553/http://forums.obsidian.net/topic/25061-age-of-the-characters/?p=184142}}</ref>\n|death=\n|species=[[Human/Legends|Human]]/[[Echani/Legends|Echani]] [[Hybrid/Legends|hybrid]]<ref name="TSL">\'\'[[Star Wars: Knights of the Old Republic II: The Sith Lords]]\'\'</ref>\n|gender=[[Gender/Legends|Female]]<ref name="TSL" />\n|height=\n|mass=\n|hair=White<ref name="TSL" />\n|eyes=Blue<ref name="TSL" />\n|skin=\n|cyber=\n|affiliation=*[[Handmaiden Sisters]]<ref name="TSL" />\n*[[Lost Jedi]]<ref name="TSL" />\n|masters=*[[Atris]] {{C|Mistress}}<ref name="TSL" />\n*[[Meetra Surik]] {{C|informal [[Jedi Master/Legends|Jedi Master]]}}<ref name="TSL" />\n|apprentices=}}\n{{Quote|When you risk pain or death for another, there is no truer test of your beliefs and strength.|Brianna|Star Wars: Knights of the Old Republic II: The Sith Lords}}\n\'\'\'Brianna\'\'\', also known as "\'\'\'The Last Handmaiden\'\'\'," was a half-[[Human/Legends|Human]], half-[[Echani/Legends|Echani]] [[Hybrid/Legends|hybrid]] fighter of [[Jedi/Legends|Jedi]] heritage. The illegitimate daughter to the famous Echani [[General/Legends|General]] [[Yusanis]] and [[Jedi Master/Legends|Jedi Master]] [[Arren Kae]], both of whom fought in the [[Mandalorian Wars]], she later served along with her five half-sisters as the [[Handmaiden Sisters]] under Jedi Master [[Atris]] in the period following the [[Jedi Civil War]]. During her service to Atris at the [[Telosian Jedi Academy|Jedi Academy]] on [[Telos IV]], Brianna met [[Meetra Surik]], also known as the Jedi Exile, and was subsequently tasked with accompanying her on her mission to seek out the [[Lost Jedi]], Jedi Masters who survived the [[First Jedi Purge]]. As Surik\'s companion, Brianna helped battle against numerous adversaries, including the [[Sith Triumvirate]].\n\nDuring the journey, Brianna trained Surik in [[Echani (martial art)/Legends|Echani]] techniques and eventually received [[Jedi training/Legends|Jedi training]] from Surik in return, becoming one of the [[Lost Jedi|first new members]] of the Jedi Order after the Purge. In accepting such training, however, she broke her oath to Atris. The Jedi Master labeled her a traitor, resulting in a confrontation between Brianna, her sisters and her former master. According to the predictions of [[Kreia]], Brianna would become instrumental in the reconstruction of the [[Jedi Order/Legends|Jedi Order]] and succeed Atris as its lead [[Jedi historian]].\n\n==Biography==\n===Early life===\n{{Quote|I knew her mother. She was a Jedi Knight&mdash;a master, named Arren Kae. Jedi are forbidden to have children, and when the crime finally came to light almost a decade later, Kae was exiled. She joined the Mandalorian Wars after the shame of her birth was revealed.|Kreia|Star Wars: Knights of the Old Republic II: The Sith Lords}}\n[[File:Briannafull.jpg|thumb|left|120px|Brianna, the last handmaiden]]\nBrianna was born in [[3976 BBY]]<ref name="age" /> as the result of a forbidden union between [[General/Legends|General]] [[Yusanis]] and [[Jedi Master/Legends|Jedi Master]] [[Arren Kae]]. Yusanis, a master [[Echani/Legends|Echani]] combatant of the Republic world [[Eshan/Legends|Eshan]], was married to another woman to whom he had fiv ...
#  Row(id=10, ns=0, redirect=None, restrictions=None, revision=Row(comment='Bot: Adding {{Film}} template', contributor=Row(id=46118473, ip=None, username='PLUMEBOT'), format='text/x-wiki', id=11147993, minor='', model='wikitext', parentid=10842344, sha1='4q5i10j5245vjs4nsozqm9txzsjc3ry', text=Row(_VALUE='{{Top|ffa|leg}}\n{{Youmay|the [[Jedi High Council/Legends|Jedi Councilor]]|the [[Atris (officer)|officer]]}}\n{{Cleanup}}\n{{Character\n|type=Jedi\n|image=[[File:Atris_head.jpg]]\n|name=Atris\n|homeworld=\n|birth=\n|death=\n|species=[[Human/Legends|Human]]<ref name="KotOR CG">\'\'[[Knights of the Old Republic Campaign Guide]]\'\'</ref>\n|gender=[[Gender/Legends|Female]]<ref name="KotOR CG" />\n|height=\n|mass=\n|hair=[[Color/Legends|White]]<ref name="TSL">\'\'[[Star Wars: Knights of the Old Republic II: The Sith Lords]]\'\'</ref>\n|eyes=Blue<ref name="TSL" />\n|skin=Light<ref name="TSL" />\n|cyber=\n|affiliation=*[[Jedi Order/Legends|Jedi Order]]<ref name="TSL" />\n**[[Jedi High Council/Legends|Jedi High Council]]<ref name="TSL" />\n**[[Lost Jedi]]<ref name="TSL" />\n*[[Galactic Republic/Legends|Galactic Republic]]<ref name="TSL" />\n|masters=\n|apprentices=}}\n{{Quote|The knowledge of the Sith&hellip; and the Jedi, is what I am. It is my attempt to hold on to the past&hellip; to try and protect the future. \'\'[&hellip;]\'\' I tied my life, my decisions to the Jedi. Perhaps only in separating myself from the Jedi can I become myself again, learn who I am.|Atris|Star Wars: Knights of the Old Republic II: The Sith Lords}}\n\'\'\'Atris\'\'\' was a [[Human/Legends|Human]] [[Gender/Legends|female]] who served as a [[Jedi historian]], and later as a [[Jedi Master/Legends|Jedi Master]] and [[Jedi High Council/Legends|Jedi Council]] member during the [[Mandalorian Wars]] and the [[Jedi Civil War]]. She was deeply committed to the [[Jedi Order/Legends|Order]] and was a fierce adherent of the [[Jedi Code/Legends|Jedi Code]]. But Atris\' faith in the righteousness of the Jedi wavered when her personal hero, [[Meetra Surik]], turned her back on the Council to join rogue Knights [[Revan/Legends|Revan]] and [[Darth Malak|Malak]] and their [[Revanchist|faction]] of Jedi during the Mandalorian Wars. Atris chose not to go to war, but this decision left her bitter and conflicted.\n\nWhen Surik returned to face the Council\'s judgment after the devastating events of the [[Battle of Malachor V]], Atris was the first to condemn her, suggesting that she had fallen to the dark side just as Revan had. Over time, Atris grew to hate Surik for complicating her black-and-white view of the [[Jedi/Legends|Jedi]], the [[Sith/Legends|Sith]], and [[The Force/Legends|the Force]]. During the [[Dark Wars]], Atris called a secret Jedi [[Conclave at Katarr|convocation]] on the [[Miraluka/Legends|Miraluka]] world of [[Katarr/Legends|Katarr]] in an attempt to find the threat that was stalking the Jedi. She then leaked knowledge of the conclave\'s existence in the hopes of drawing out the Sith. She succeeded, but with dire consequences; [[Darth Nihilus]] devastated the surface of the planet, wiping out all life on Katarr, including the Jedi gathered there.\n\nHowever, Atris survived, and she remained in seclusion, surrounding herself with [[Echani/Legends|Echani]] [[Handmaiden Sisters|Handmaidens]] who could not feel the Force. She planned to rebuild the Jedi Order, and established a [[Telosian Jedi Academy|Jedi Academy]] in the old irrigation system on [[Telos IV]]. However, she was heavily influenced by the many [[Sith holocron/Legends|Sith holocrons]] she had collected in her efforts to find and understand the Sith. The holocrons fed her bitterness, and she slowly and quietly fell to the dark side, consequently becoming the new \'\'\'Darth Traya\'\'\', the \'\'\'Queen of Betrayal\'\'\'. Per the machinations of her mentor, [[Kreia]], Surik and the new [[Darth/Legends|Darth]] Traya confronted each other once more on Telos, where Surik convinced Atris to turn away fr ...

# %%
df.write.format("mongo").mode("append").save()

# %%
from pymongo import MongoClient
import wikitextparser as wtp
from lxml import html

# %%
client = MongoClient("mongodb://root:helloworld@127.0.0.1/wiki.starwars?authSource=admin")

# %%
collection = client.wiki.wookiepedia.characters

# %%
def select_character(parsed_item):
    for template in parsed_item.templates:
        if template.name.startswith('Character') or template.name.startswith('Droid'):
            return template
    return None

def clean_value(value):
    tree = html.fromstring(f'<span>{value}</span>')
    value = tree.text_content().strip()

    value = wtp.remove_markup(value)

    parsed = wtp.parse(value)
    if parsed.get_lists():
        value = ','.join(map(lambda x: x.strip(), parsed.get_lists()[0].items))

    return value

def extract_args(template):
    args = {}
    for arg in getattr(template, 'arguments', []):
        args[arg.name.strip()] = wtp.remove_markup(clean_value(arg.value.strip()))
    return args

# %%
from tqdm import tqdm

for record in tqdm(collection.find()):
    parsed = wtp.parse(record['text'])

    character = select_character(parsed)
    properties = extract_args(character)
    properties['is_droid'] = character and character.name.startswith('Droid')

    collection.update_one(
        {'_id': record['_id']},
        {'$set': {'properties': properties}}
    )
# Out:
# 9979it [01:00, 163.59it/s]

# %% [markdown]
# # Mongo Queries
#
# ```sql
# db.starwars.updateMany(
#     {},
#     [
#         {"$set": {"text": "$revision.text._VALUE"}}
#     ]
# )
#
#
#
# db.wookiepedia.characters.insertMany(
#     db.getCollection("starwars")
#             .find({'text': /\{\{(Character|Droid)/}).toArray()
# )
#
# db.wookiepedia.characters.deleteMany(
# {
# title: /^(Talk:|File:|User:|Forum:)/
# }
# )
#
# db.wookiepedia.characters.deleteMany(
# {
# title: /\/Legends$/
# }
# )
#
# db.wookiepedia.characters.deleteMany(
# {text: /^\{\{Top\|leg\}\}/}
# )
#
# db.wookiepedia.characters.deleteMany(
# {
# text: /\{\{Noncanon\|/
# }
# )
#
# db.wookiepedia.characters.deleteMany(
# {
# title: /lightsaber/
# }
# )
#
# db.wookiepedia.characters.deleteMany(
# {text: /\{\{Top\|.*real.*\}\}/}
# )
#
# db.wookiepedia.characters.deleteMany(
# {$and: [{text: /\{\{Top\|.*leg.*\}\}/}, {text: {$not: /\{\{Top\|.*legends=.*\}\}/}}, {text: {$not: /\{\{Top\|.*canon.*\}\}/}}]}
# )
# ```
